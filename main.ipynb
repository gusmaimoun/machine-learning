# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaimoun/pynychome/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
import joblib
import geopandas  as gp
import folium
from folium import plugins
import warnings
warnings.filterwarnings('ignore')
print("Setup Complete")
# Out:
# Setup Complete

# %%
data = pd.read_csv('NY-House-Dataset.csv')

# %%
data = data.drop_duplicates()

# %%
data["BROKERTITLE"] = data["BROKERTITLE"].apply(lambda row: row.removeprefix("Brokered by "))
data["TYPE"] = data["TYPE"].apply(lambda row: row.removesuffix(" for sale"))

# %%
data = data.rename(columns={"TYPE": "type",
                   "BROKERTITLE": "broker",
                   "PRICE": "price",
                   "BEDS": "beds",
                   "BATH": "baths",
                   "PROPERTYSQFT": "sqft",
                   "ADDRESS": "address",
                   "STATE": "state",
                   "MAIN_ADDRESS": "address_full",
                   "LATITUDE": "lat",
                   "LONGITUDE": "lon",
                   "SUBLOCALITY": "sub_locality"})[["type", "broker", "price", "beds", "baths", "sqft",
                                                    "address", "state", "address_full", "lat", "lon",
                                                    "sub_locality"]]

# %%
data["baths"] = data["baths"].astype("int32")

# %%
tranlations = {
    "New York": "New York County",  # Generally refers to Manhattan
    "Kings County": "Kings County",  # Brooklyn
    "Queens County": "Queens County",
    "Queens": "Queens County",
    "Richmond County": "Richmond County",  # Staten Island
    "Brooklyn": "Kings County",
    "Bronx County": "Bronx County",
    "New York County": "New York County",  # Manhattan
    "The Bronx": "Bronx County",
    "Staten Island": "Richmond County",
    "Manhattan": "New York County",
    "Riverdale": "Bronx County",  # Neighborhood in The Bronx
    "Flushing": "Queens County",  # Neighborhood in Queens
    "Coney Island": "Kings County",  # Neighborhood in Brooklyn
    "East Bronx": "Bronx County",  # Part of The Bronx
    "Brooklyn Heights": "Kings County",  # Neighborhood in Brooklyn
    "Jackson Heights": "Queens County",  # Neighborhood in Queens
    "Rego Park": "Queens County",  # Neighborhood in Queens
    "Fort Hamilton": "Kings County",  # Neighborhood in Brooklyn
    "Dumbo": "Kings County",  # Neighborhood in Brooklyn
    "Snyder Avenue": "Kings County"  # Assuming this is in Brooklyn; otherwise, needs correction
}

data["sub_locality"] = data["sub_locality"].apply(lambda row: tranlations[row])

# %%
np.any(~data["sub_locality"].str.contains("County"))
# Out:
# False

# %%
data.sort_values(by="beds", ascending=False).head(10)
# Out:
#                    type                                broker     price  beds  \
# 1143  Multi-family home        Blue Key Real Estate Brokerage  11000000    50
# 2653  Multi-family home                   NEUHAUS REALTY INC.  10700000    42
# 3276  Multi-family home           Weichert Realtors TMT Group   5980000    40
# 2488  Multi-family home      RE MAX Real Estate Professionals   3099000    36
# 765   Multi-family home                           RE MAX Edge   4380000    35
# 2265              House              Coldwell Banker Reliable   4000000    32
# 3589  Multi-family home  Coldwell Banker Reliable Real Estate   4000000    32
# 3603  Multi-family home                    BHHS Fillmore R.E.   3500000    30
# 2564  Multi-family home        Coldwell Banker American Homes   2700000    24
# 1092              House      CHRISTIE'S INT.REAL ESTATE GROUP   3500000    24
#
#       baths     sqft                    address                      state  \
# 1143     50  22035.0              8820 Avenue J         Brooklyn, NY 11236
# 2653     43  27152.0  646-662 Port Richmond Ave    Staten Island, NY 10302
# 3276     20  15500.0              35-54 95th St  Jackson Heights, NY 11372
# 2488     16  12460.0               5206 6th Ave         Brooklyn, NY 11220
# 765      16  15000.0      8699 Bay Pkwy Unit 16         Brooklyn, NY 11214
# 2265     12   7188.0             150 E 105th St         New York, NY 10029
# 3589     12   7200.0             154 E 105th St         New York, NY 10029
# 3603     20  18400.0           1319 Newkirk Ave         Brooklyn, NY 11230
# 2564     24  18936.0   3520 Newkirk Ave Unit 24         Brooklyn, NY 11203
# 1092      8   9500.0              29 Hampton Pl         Brooklyn, NY 11213
#
#                                           address_full        lat        lon  \
# 1143                   8820 Avenue JBrooklyn, NY 11236  40.637696 -73.904836
# 2653  646-662 Port Richmond AveStaten Island, NY 10302  40.627671 -74.142352
# 3276            35-54 95th StJackson Heights, NY 11372  40.751468 -73.872619
# 2488                    5206 6th AveBrooklyn, NY 11220  40.642652 -74.009674
# 765            8699 Bay Pkwy Unit 16Brooklyn, NY 11214  40.599715 -73.995694
# 2265                  150 E 105th StNew York, NY 10029  40.791288 -73.946522
# 3589                  154 E 105th StNew York, NY 10029  40.791206 -73.946512
# 3603                1319 Newkirk AveBrooklyn, NY 11230  40.635180 -73.964614
# 2564        3520 Newkirk Ave Unit 24Brooklyn, NY 11203  40.640181 -73.942939
# 1092                   29 Hampton PlBrooklyn, NY 11213  40.671795 -73.940735
#
#          sub_locality
# 1143     Kings County
# 2653  Richmond County
# 3276    Queens County
# 2488     Kings County
# 765      Kings County
# 2265  New York County
# 3589  New York County
# 3603     Kings County
# 2564     Kings County
# 1092     Kings County

# %%
plt.boxplot(data["beds"])
plt.title("number of beds per unit")
plt.show()

# %%
plt.boxplot(data["price"])
plt.title("price per unit")
plt.show()

# %%
data.sort_values(by="price", ascending=False).head(10)
# Out:
#            type                                             broker  \
# 304       House                              ANNE LOPA REAL ESTATE
# 1         Condo                                            Serhant
# 69    Townhouse  Sotheby's International Realty - East Side Man...
# 1075      Co-op                                            COMPASS
# 141       House                  Douglas Elliman - 575 Madison Ave
# 99        House                  Douglas Elliman - 575 Madison Ave
# 4     Townhouse  Sotheby's International Realty - East Side Man...
# 626       Condo                Nest Seekers International, Midtown
# 1453      Co-op                                 Corcoran East Side
# 3388      Co-op  Sotheby's International Realty - East Side Man...
#
#            price  beds  baths          sqft  \
# 304   2147483647     7      6  10000.000000
# 1      195000000     7     10  17545.000000
# 69      65000000     3      2  15200.000000
# 1075    60000000     8      8   2184.207862
# 141     56000000    11     10  24000.000000
# 99      55000000     8      8  12000.000000
# 4       55000000     7      2  14175.000000
# 626     50000000     6      6   6569.000000
# 1453    48000000     5      2   2184.207862
# 3388    45000000     5      2   2184.207862
#
#                                                 address                state  \
# 304                                  6659-6675 Amboy Rd   New York, NY 10309
# 1     Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 69                                          4 E 79th St   New York, NY 10075
# 1075                                960 5th Ave Unit 12  Manhattan, NY 10075
# 141                                         9 W 54th St   New York, NY 10019
# 99                                      25 Riverside Dr   New York, NY 10023
# 4                                           5 E 64th St   New York, NY 10065
# 626                               100 Vandam St Apt 20A   New York, NY 10013
# 1453                              740 Park Ave # 4 & 5B   New York, NY 10021
# 3388                                   4 E 66th St Fl 7   New York, NY 10065
#
#                                            address_full        lat        lon  \
# 304                6659-6675 Amboy RdNew York, NY 10309  40.518484 -74.224418
# 1     Central Park Tower Penthouse-217 W 57th New Yo...  40.766393 -73.980991
# 69                        4 E 79th StNew York, NY 10075  40.776561 -73.963317
# 1075             960 5th Ave Unit 12Manhattan, NY 10075  40.775642 -73.964247
# 141                       9 W 54th StNew York, NY 10019  40.761600 -73.976191
# 99                    25 Riverside DrNew York, NY 10023  40.782238 -73.984632
# 4                         5 E 64th StNew York, NY 10065  40.767224 -73.969856
# 626             100 Vandam St Apt 20ANew York, NY 10013  40.726633 -74.008832
# 1453            740 Park Ave # 4 & 5BNew York, NY 10021  40.770752 -73.964528
# 3388                 4 E 66th St Fl 7New York, NY 10065  40.768301 -73.969734
#
#          sub_locality
# 304   Richmond County
# 1     New York County
# 69    New York County
# 1075  New York County
# 141   New York County
# 99    New York County
# 4     New York County
# 626   New York County
# 1453  New York County
# 3388  New York County

# %%
data = data.drop(1143)
data["price"][304] = 2290700
data["price"][1] = 19500000

# %%
data[["sub_locality", "price"]].groupby("sub_locality").agg(["min", "max", "std", "mean", "median"])
# Out:
#                   price
#                     min       max           std          mean     median
# sub_locality
# Bronx County      49500  14000000  1.027218e+06  7.624211e+05   599000.0
# Kings County       5800  31500000  1.928083e+06  1.439236e+06   949000.0
# New York County    2494  65000000  7.010165e+06  4.081857e+06  1479000.0
# Queens County    100000  15000000  8.013789e+05  8.243145e+05   669000.0
# Richmond County   90000  16800000  1.003193e+06  8.912633e+05   728000.0

# %%
data.describe()
# Out:
#               price         beds        baths          sqft          lat  \
# count  4.586000e+03  4586.000000  4586.000000   4586.000000  4586.000000
# mean   1.873254e+06     3.355648     2.343873   2173.382446    40.713949
# std    4.087458e+06     2.537266     1.840932   2264.429959     0.087740
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.638624
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726691
# 75%    1.497250e+06     4.000000     3.000000   2184.207862    40.771913
# max    6.500000e+07    42.000000    43.000000  65535.000000    40.912729
#
#                lon
# count  4586.000000
# mean    -73.941592
# std       0.101286
# min     -74.253033
# 25%     -73.987431
# 50%     -73.949146
# 75%     -73.869418
# max     -73.702450

# %%
data.head()
# Out:
#         type                                             broker     price  \
# 0      Condo                    Douglas Elliman  -111 Fifth Ave    315000
# 1      Condo                                            Serhant  19500000
# 2      House                                         Sowae Corp    260000
# 3      Condo                                            COMPASS     69000
# 4  Townhouse  Sotheby's International Realty - East Side Man...  55000000
#
#    beds  baths     sqft                                            address  \
# 0     2      2   1400.0                               2 E 55th St Unit 803
# 1     7     10  17545.0  Central Park Tower Penthouse-217 W 57th New Yo...
# 2     4      2   2015.0                                   620 Sinclair Ave
# 3     3      1    445.0                            2 E 55th St Unit 908W33
# 4     7      2  14175.0                                        5 E 64th St
#
#                      state                                       address_full  \
# 0       New York, NY 10022             2 E 55th St Unit 803New York, NY 10022
# 1       New York, NY 10019  Central Park Tower Penthouse-217 W 57th New Yo...
# 2  Staten Island, NY 10312            620 Sinclair AveStaten Island, NY 10312
# 3      Manhattan, NY 10022         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4       New York, NY 10065                      5 E 64th StNew York, NY 10065
#
#          lat        lon     sub_locality
# 0  40.761255 -73.974483  New York County
# 1  40.766393 -73.980991  New York County
# 2  40.541805 -74.196109  Richmond County
# 3  40.761398 -73.974613  New York County
# 4  40.767224 -73.969856  New York County

# %%
X = data.drop(columns="price")
y = data["price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                                random_state=0)

# %%
num_features = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_features = X_train.select_dtypes(include=['object']).columns

num_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# pipeline for nums and cats
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_features),
        ('cat', cat_transformer, cat_features)
    ])

# %%
model1 = RandomForestRegressor(n_estimators=100, random_state=0)
model2 = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0)
model3 = LinearRegression()
model4 = SVR(C=0.1, coef0=2.0, gamma=1, kernel='poly')
model5 = ElasticNet(random_state=10)

# %%
# making an ensemble model using VotingRegressor
ensemble_model = VotingRegressor(estimators=[
    ('rf', model1),
    ('gb', model2),
    ('lr', model3),
    ('sr', model4),
    ('en', model5)])

ensemble_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                    ('model', ensemble_model)
                                    ])

ensemble_pipeline.fit(X_train, y_train)

#get predictions
ensemble_preds = ensemble_pipeline.predict(X_test)
np.savetxt('ensemble_preds.csv', ensemble_preds, delimiter=',')

# %%
ensemble_score = mean_absolute_error(y_test, ensemble_preds)
print('Ensemble MAE:', ensemble_score)
# Out:
# Ensemble MAE: 854474.4436147555

# %%
map = folium.Map(location=[data.lat.mean(), data.lon.mean()], zoom_start=11.4)

MAX = np.log(data.price.max())
hm = plugins.HeatMap([[row["lat"], row["lon"], np.log(row["price"])/MAX] for index, row in data.iterrows()],
                     gradient={0.85: 'blue', 0.95: 'lime', 1: 'red'})

hm.add_to(map)

map.save('heatmap.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bd098ec55451a0ab46e97461de12ce4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bd098ec55451a0ab46e97461de12ce4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bd098ec55451a0ab46e97461de12ce4 = L.map(
#                 &quot;map_3bd098ec55451a0ab46e97461de12ce4&quot;,
#                 {
#                     center: [40.71394899805931, -73.94159235970344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb4c9aa4fcaf9aa57372cef012dacf36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cb4c9aa4fcaf9aa57372cef012dacf36.addTo(map_3bd098ec55451a0ab46e97461de12ce4);
#
#
#             var heat_map_b08d414d7176d7238c8b3ee4430e7c0d = L.heatLayer(
#                 [[40.761255, -73.9744834, 0.7037465159030228], [40.7663935, -73.9809909, 0.9330750615792041], [40.5418051, -74.1961086, 0.6930799179241875], [40.7613979, -73.9746128, 0.6193399145560816], [40.7672235, -73.9698561, 0.990714005923677], [40.6743632, -73.9587248, 0.7473331424791534], [40.809448, -73.946777, 0.7620718285093021], [40.5950017, -74.1064235, 0.9247906577106237], [40.8215857, -73.8740892, 0.6941387452256519], [40.6157378, -73.9696944, 0.7223237246945655], [40.8248699, -73.9229829, 0.7134382545006022], [40.6249962, -74.1553058, 0.747252523534481], [40.7531191, -73.8818757, 0.6928657105199618], [40.7438639, -73.8745722, 0.7210458120324327], [40.7382981, -74.0058899, 0.7617930423169779], [40.5406209, -74.1671632, 0.7346263912641595], [40.7607676,